# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")
# (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"

# %%
table = pd.read_csv("fifa2.csv", index_col = "Date", parse_dates=True)

# %%
table

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data = table['ARG'])

# %%
tb = pd.read_csv("fifa.csv", index_col = "id")
tb

# %%
plt.figure(figsize=(10,6))
plt.title = "this"

sns.barplot(x = tb[" name"].head(10), y = tb[" rating"].head(10))
# sns.lineplot(x = tb[" name"].head(1000), y = tb[" rating"].head(1000))

# %%
plt.figure(figsize=(10,6))
plt.title = "that"
sns.heatmap(data =  table.head(), annot = True)

# %%
tbl = pd.read_csv("insurance.csv")

# %%
r = tbl.groupby("sex").agg(["count", "max", "min", "var"])

# %%
r

# %%
sns.scatterplot(x = tbl['bmi'], y = tbl['charges'], hue=tbl['smoker']) 
sns.regplot(x = tbl['bmi'], y = tbl['age'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %%
sns.swarmplot(x=tbl['smoker'], y=tbl['charges'])
# Out:
# C:\Users\dbaks\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
flow = pd.read_csv("iris.csv")
flow
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.histplot(x=flow["SepalLengthCm"],kde = False)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.kdeplot(data=flow['SepalLengthCm'], shade=True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.jointplot(x = flow["SepalLengthCm"], y = flow["SepalWidthCm"], kind = "kde")
