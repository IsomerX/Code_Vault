# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from sklearn.datasets import load_boston

# %%
sns.set_style('whitegrid')

# %%
boston = load_boston()

# %%
boston_df = pd.DataFrame(boston.data)

# %%
boston_df.columns = boston.feature_names

# %%
boston_df['Prices'] = boston.target

# %%
X = boston_df.RM

# %%
X = np.vstack(boston_df.RM)

# %%
X.resize((len(X),1))

# %%
X = np.append(X, np.ones((506,1)),axis = 1)

# %%
Y = boston_df.Prices

# %%
m, b = np.linalg.lstsq(X,Y)[0]
# Out:
# <ipython-input-30-761e189a9409>:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, b = np.linalg.lstsq(X,Y)[0]

# %%
plt.plot(boston_df.RM, boston_df.Prices, 'o')
x = boston_df.RM
plt.plot(x, m*x+b,'r',label = "best straight line")
plt.show()

# %% [markdown]
# # Class 3

# %%
result = np.linalg.lstsq(X,Y)

error_tot = result[1]

rmse = np.sqrt(error_tot/len(X))
print(f"rmse is {error_tot}")
# Out:
# rmse is [22061.87919621]
# <ipython-input-34-83a2eefe17b4>:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   result = np.linalg.lstsq(X,Y)
